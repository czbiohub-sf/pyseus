# %%
import sys
sys.path.append('../')
import pandas as pd
from pyseus.plotting import plotly_volcano as pv
import imp

# %% [markdown]
# ### Import enrichment/pval calculated database

# %%
root = '../data/demo_nativeIP_elution_optimization/'
filename = 'pval_enrichment_table_20210330.pkl'

master = pd.read_pickle(root + filename)

# %% [markdown]
# ### Volcano plot!

# %%
imp.reload(pv)
pv.simple_volcano(master, 'On_Bead_1uL_LAMP1', [4,2], width=400, height=400)
# Out:
# Number of Significant Hits: 2

# %% [markdown]
# ### List of Baits

# %%
list(set([x[0] for x in list(master)]))
# Out:
# ['SDS_WT',
#  'On_Bead_2uL_LAMP1',
#  'PPX_TOMM20',
#  'Triton_WT',
#  'Glycine_Low_pH_PEX3',
#  'On_Bead_2uL_TOMM20',
#  'On_Bead_1uL_LAMP1',
#  'On_Bead_1uL_TOMM20',
#  'PPX_WT',
#  'SDS_TOMM20',
#  'Glycine_Low_pH_WT',
#  'Glycine_Low_pH_TOMM20',
#  'gene_names',
#  'Peptide_Elution_FASP_TOMM20',
#  'On_Bead_1uL_WT',
#  'PPX_PEX3',
#  'Triton_PEX3',
#  'SDS_PEX3',
#  'SDS_LAMP1',
#  'Triton_LAMP1',
#  'On_Bead_1uL_PEX3',
#  'PPX_LAMP1',
#  'On_Bead_2uL_PEX3',
#  'Glycine_Low_pH_LAMP1',
#  'Triton_TOMM20',
#  'Peptide_Elution_FASP_LAMP1',
#  'On_Bead_2uL_WT',
#  'Peptide_Elution_FASP_WT',
#  'Peptide_Elution_FASP_PEX3']
