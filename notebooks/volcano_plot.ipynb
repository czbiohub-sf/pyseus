# %%
import sys
sys.path.append('../')
import pandas as pd
from pyseus.plotting import plotly_volcano as pv

# %% [markdown]
# ### Import enrichment/pval calculated database

# %%
root = '../data/20210719_Infected_Cell_All_Samples/'
analysis = '20210726/'
filename = 'pval_tables.pkl'

master = pd.read_pickle(root + analysis + filename)

# %% [markdown]
# ### Volcano plot!

# %%
# fcd = [curvature, offset]
pv.simple_volcano(master.simple_pval_table, '20210719_TOMM20-uninfected', fcd= [4,3.8], width=400, height=400)
# Out:
# Number of Significant Hits: 17

# %% [markdown]
# ### List of Baits

# %%
list(set([x[0] for x in list(master.simple_pval_table)]))
# Out:
# ['20210719_PEX3-uninfected',
#  '20210719_untagged-infected',
#  '20210719_TOMM20-infected',
#  '20210719_untagged-uninfected',
#  '20210719_GPR107-uninfected',
#  '20210719_TOMM20-uninfected',
#  '20210719_LAMP1-infected',
#  '20210719_RTN4-infected',
#  '20210719_GPR107-infected',
#  '20210719_PEX3-infected',
#  '20210719_LAMP1-uninfected',
#  '20210719_RTN4-uninfected',
#  'gene_names']
